# %%
import pandas as pd
import altair as alt
import pubchempy as pcp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Crear dataframe con los datos de las perturbaciones en LINCS.

# %%
df = pd.read_csv('GSE92742_Broad_LINCS_pert_info.txt', sep = '\t', usecols = [0, 1]) # Crear df importando datos del archivo (sólo cols de interés), separándolos por una sangría y sin headers por columna
display(df) # Print con mejor visualización
# Out:
#                   pert_id  pert_iname
# 0                   56582        AKT2
# 1                    5981        HSF1
# 2                    7150      NFE2L2
# 3                ABL1_G2A        ABL1
# 4              ABL1_T315I        ABL1
# ...                   ...         ...
# 51378  ccsbBroad304_99991  LUCIFERASE
# 51379  ccsbBroad304_99994        lacZ
# 51380  ccsbBroad304_99997        eGFP
# 51381               dsRED       DSRED
# 51382             renilla     RENILLA
#
# [51383 rows x 2 columns]

# %% [markdown]
# 2. Preprocesar la base de datos eliminando los duplicados, datos vacíos, etc.

# %%
df = df.dropna() # Eliminar filas sin información
df = df.drop_duplicates(['pert_id']) # Elimina información duplicada en las columnas indicadas
display(df) # Print con mejor visualización
# Out:
#                   pert_id  pert_iname
# 0                   56582        AKT2
# 1                    5981        HSF1
# 2                    7150      NFE2L2
# 3                ABL1_G2A        ABL1
# 4              ABL1_T315I        ABL1
# ...                   ...         ...
# 51378  ccsbBroad304_99991  LUCIFERASE
# 51379  ccsbBroad304_99994        lacZ
# 51380  ccsbBroad304_99997        eGFP
# 51381               dsRED       DSRED
# 51382             renilla     RENILLA
#
# [51383 rows x 2 columns]

# %% [markdown]
# 3. Contar el número de perturbaciones por molécula.

# %%
final = df.value_counts("pert_iname", sort = True) # Cuenta el número de filas asociadas a cada valor único de la columna indicada y los ordena en orden descendente
print(final) # Imprime el resultado
# Out:
# pert_iname
# BCR-ABL          42
# EGFR             32
# BRAF             30
# ERBB3            24
# PTK2             24
#                  ..
# BRD-K46959535     1
# BRD-K46943684     1
# BRD-K46936109     1
# BRD-K46932228     1
# BRD-K76269493     1
# Length: 28957, dtype: int64

# %%
df_final = final.rename_axis('drug_name').reset_index(name='num_perts') # Convierte la estructura de datos 'final' en un dataframe
display(df_final) # Print con mejor visualización
# Out:
#            drug_name  num_perts
# 0            BCR-ABL         42
# 1               EGFR         32
# 2               BRAF         30
# 3              ERBB3         24
# 4               PTK2         24
# ...              ...        ...
# 28952  BRD-K46959535          1
# 28953  BRD-K46943684          1
# 28954  BRD-K46936109          1
# 28955  BRD-K46932228          1
# 28956  BRD-K76269493          1
#
# [28957 rows x 2 columns]

# %% [markdown]
# 4. Identificar el ID de PubChem en los antidepresivos enlistados en SIDER 4.1.

# %%
ad = pd.read_csv('drug_atc.tsv', sep = '\t', usecols = [1], header = None) # Crear df importando datos del archivo (sólo cols de interés), separándolos por una sangría y sin headers por columna
display(ad) # Print con mejor visualización
# Out:
#             1
# 0     A16AA01
# 1     L03AA03
# 2     N03AG03
# 3     L01XD04
# 4     V03AF03
# ...       ...
# 1555  J01AA12
# 1556  J01AA04
# 1557  S01LA03
# 1558  C10AC01
# 1559  L03AB05
#
# [1560 rows x 1 columns]

# %%
ad.rename(columns = {1:'ATC_code'}, inplace = True) # Cambiar nombre a las columnas
display(ad) # Print con mejor visualización
# Out:
#      ATC_code
# 0     A16AA01
# 1     L03AA03
# 2     N03AG03
# 3     L01XD04
# 4     V03AF03
# ...       ...
# 1555  J01AA12
# 1556  J01AA04
# 1557  S01LA03
# 1558  C10AC01
# 1559  L03AB05
#
# [1560 rows x 1 columns]

# %%
def antidepressants(i):
    if str(i[0:4]) == 'N06A': # ATC_code para antidepresivos es 'N06A...'
        return True
    else:
        return False

# %%
ad['AD'] = ad.ATC_code.map(antidepressants) # Utiliza la función con los datos de la columna 'ATC_code' y asigna True/False según si son antidepresivos o no
display(ad) # Print con mejor visualización
# Out:
#      ATC_code     AD
# 0     A16AA01  False
# 1     L03AA03  False
# 2     N03AG03  False
# 3     L01XD04  False
# 4     V03AF03  False
# ...       ...    ...
# 1555  J01AA12  False
# 1556  J01AA04  False
# 1557  S01LA03  False
# 1558  C10AC01  False
# 1559  L03AB05  False
#
# [1560 rows x 2 columns]

# %%
ad = ad[ad['AD'] == True] # Elimina todos los datos que sean False en la columna 'AD', es decir, los que no son antidepresivos
ad = ad.drop(['AD'], axis = 1) # Elimina la columna que define si es un antidepresivo o no
display(ad) # Print con mejor visualización
# Out:
#      ATC_code
# 51    N06AX12
# 159   N06AA09
# 165   N06AA17
# 307   N06AB04
# 308   N06AB10
# 319   N06AA04
# 355   N06AA01
# 419   N06AA16
# 422   N06AA12
# 493   N06AB03
# 503   N06AB08
# 569   N06AF03
# 582   N06AA02
# 603   N06AF01
# 656   N06AA21
# 712   N06AX03
# 725   N06AX11
# 728   N06AG02
# 748   N06AX06
# 781   N06AA10
# 821   N06AB05
# 901   N06AA11
# 942   N06AB06
# 1022  N06AF04
# 1024  N06AX05
# 1047  N06AA06
# 1060  N06AX16
# 1212  N06AX17
# 1236  N06AX21
# 1260  N06AX18
# 1290  N06AX22
# 1328  N06AX23

# %% [markdown]
# 5. Identificar el nombre del antidepresivo enlistado en SIDER 4.1 según su código ATC.

# %%
nombres = pd.read_csv('names_ATC.csv', sep = ',', usecols = ['atc_code', 'atc_name']) # Crear df importando datos del archivo (sólo cols de interés), separándolos por una sangría y sin headers por columna
display(nombres) # Print con mejor visualización
# Out:
#      atc_code                         atc_name
# 0           A  ALIMENTARY TRACT AND METABOLISM
# 1         A01      STOMATOLOGICAL PREPARATIONS
# 2        A01A      STOMATOLOGICAL PREPARATIONS
# 3       A01AA       Caries prophylactic agents
# 4     A01AA01                  sodium fluoride
# ...       ...                              ...
# 6966  V10XX01           sodium phosphate (32P)
# 6967  V10XX02       ibritumomab tiuxetan (90Y)
# 6968  V10XX03        radium (223Ra) dichloride
# 6969  V10XX04   lutetium (177Lu) oxodotreotide
# 6970      V20               SURGICAL DRESSINGS
#
# [6971 rows x 2 columns]

# %%
names = nombres.loc[nombres['atc_code'].isin(ad['ATC_code'])] # Localizar todas las columnas en el dataframe directorio con los códigos ATC para encontrar los nombres de dichos medicamentos
names = names.dropna() # Eliminar filas sin información
names = names.drop_duplicates(['atc_code', 'atc_name']) # Elimina información duplicada en las columnas indicadas
display(names) # Print con mejor visualización
# Out:
#      atc_code         atc_name
# 5284  N06AA01      desipramine
# 5285  N06AA02       imipramine
# 5288  N06AA04     clomipramine
# 5291  N06AA06     trimipramine
# 5295  N06AA09    amitriptyline
# 5297  N06AA10    nortriptyline
# 5299  N06AA11    protriptyline
# 5300  N06AA12          doxepin
# 5306  N06AA16        dosulepin
# 5307  N06AA17        amoxapine
# 5310  N06AA21      maprotiline
# 5315  N06AB03       fluoxetine
# 5316  N06AB04       citalopram
# 5318  N06AB05       paroxetine
# 5319  N06AB06       sertraline
# 5321  N06AB08      fluvoxamine
# 5323  N06AB10     escitalopram
# 5325  N06AF01    isocarboxazid
# 5327  N06AF03       phenelzine
# 5328  N06AF04  tranylcypromine
# 5332  N06AG02      moclobemide
# 5337  N06AX03        mianserin
# 5339  N06AX05        trazodone
# 5340  N06AX06       nefazodone
# 5345  N06AX11      mirtazapine
# 5346  N06AX12        bupropion
# 5350  N06AX16      venlafaxine
# 5351  N06AX17      milnacipran
# 5352  N06AX18       reboxetine
# 5354  N06AX21       duloxetine
# 5355  N06AX22      agomelatine
# 5356  N06AX23   desvenlafaxine

# %%
def verifyCID(drug_name): # Asignar o corroborar 'pubchem cid'
    for c in pcp.get_compounds(str(drug_name), 'name'): # Buscar el CID de PubChem según el nombre del compuesto
        return c.cid # Devolver el CID de PubChem

# %%
names['pubchem_cid'] = names.atc_name.map(verifyCID) # Utiliza la función 'verifyCID' para buscar los CIDs con los datos de los nombres de los compuestos en el df, y genera una nueva columna
display(names) # Print con mejor visualización
# Out:
#      atc_code         atc_name  pubchem_cid
# 5284  N06AA01      desipramine         2995
# 5285  N06AA02       imipramine         3696
# 5288  N06AA04     clomipramine         2801
# 5291  N06AA06     trimipramine         5584
# 5295  N06AA09    amitriptyline         2160
# 5297  N06AA10    nortriptyline         4543
# 5299  N06AA11    protriptyline         4976
# 5300  N06AA12          doxepin       667477
# 5306  N06AA16        dosulepin      5284550
# 5307  N06AA17        amoxapine         2170
# 5310  N06AA21      maprotiline         4011
# 5315  N06AB03       fluoxetine         3386
# 5316  N06AB04       citalopram         2771
# 5318  N06AB05       paroxetine        43815
# 5319  N06AB06       sertraline        68617
# 5321  N06AB08      fluvoxamine      5324346
# 5323  N06AB10     escitalopram       146570
# 5325  N06AF01    isocarboxazid         3759
# 5327  N06AF03       phenelzine         3675
# 5328  N06AF04  tranylcypromine         5530
# 5332  N06AG02      moclobemide         4235
# 5337  N06AX03        mianserin         4184
# 5339  N06AX05        trazodone         5533
# 5340  N06AX06       nefazodone         4449
# 5345  N06AX11      mirtazapine         4205
# 5346  N06AX12        bupropion          444
# 5350  N06AX16      venlafaxine         5656
# 5351  N06AX17      milnacipran        65833
# 5352  N06AX18       reboxetine       127151
# 5354  N06AX21       duloxetine        60835
# 5355  N06AX22      agomelatine        82148
# 5356  N06AX23   desvenlafaxine       125017

# %%
display(df_final) # Print con mejor visualización
# Out:
#            drug_name  num_perts
# 0            BCR-ABL         42
# 1               EGFR         32
# 2               BRAF         30
# 3              ERBB3         24
# 4               PTK2         24
# ...              ...        ...
# 28952  BRD-K46959535          1
# 28953  BRD-K46943684          1
# 28954  BRD-K46936109          1
# 28955  BRD-K46932228          1
# 28956  BRD-K76269493          1
#
# [28957 rows x 2 columns]

# %%
final_graph = df_final.loc[df_final['drug_name'].isin(names['atc_name'])] # Encontrar las columnas con los valores 
display(final_graph)
# Out:
#              drug_name  num_perts
# 4356   tranylcypromine          3
# 4380           doxepin          3
# 4390        reboxetine          3
# 4489        paroxetine          3
# 4831       fluvoxamine          2
# 4965        sertraline          2
# 4982       mirtazapine          2
# 5045       maprotiline          2
# 6112     protriptyline          1
# 6412     nortriptyline          1
# 6506        nefazodone          1
# 6555        phenelzine          1
# 6781         trazodone          1
# 6811      trimipramine          1
# 6858       venlafaxine          1
# 12480       imipramine          1
# 12620     escitalopram          1
# 12686        dosulepin          1
# 12698       duloxetine          1
# 12788       fluoxetine          1
# 13027        mianserin          1
# 13063      milnacipran          1
# 13096      moclobemide          1
# 13289    isocarboxazid          1
# 13550    amitriptyline          1
# 13554        amoxapine          1
# 14380      desipramine          1
# 14429        bupropion          1
# 14579       citalopram          1
# 14609     clomipramine          1

# %% [markdown]
# 5. Graficar el resultado

# %%
alt.Chart(final_graph,
        title = alt.TitleParams('Número de perturbaciones por antidepresivo en LINCS NIH (fase 1)', anchor='middle')).mark_bar().encode(
        x = alt.X('drug_name', title = "Nombre del antidepresivo (STITCH database)"),
        y = alt.Y('num_perts', title = "Número de perturbaciones por antidepresivo"),
        color = alt.value('purple'))
# Out:
# alt.Chart(...)
