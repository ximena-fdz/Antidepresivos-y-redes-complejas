# %%
import pandas as pd

# Leer los archivos 'drug_atc' (CID - ATC) y 'drug_names' (ATC - name), y combinar ambos ordenando con base en el CID

drug_atc = pd.read_csv("drug_atc.tsv", sep="\t")
drug_names = pd.read_csv("drug_names.tsv", sep="\t")

combined_df = pd.merge(drug_atc, drug_names, on="cid")

# Mantener aquellas filas donde el ATC inicie con N06A (antidepressants)

antidepressants = combined_df[combined_df["atc"].str.startswith("N06A")]

display(antidepressants)

# Guardar archivo

antidepressants.to_csv("antidepressants.tsv", sep="\t", index=False)
# Out:
#                cid      atc       pert_iname
# 51    CID100000444  N06AX12        bupropion
# 159   CID100002160  N06AA09    amitriptyline
# 165   CID100002170  N06AA17        amoxapine
# 307   CID100002771  N06AB04       citalopram
# 308   CID100002771  N06AB10       citalopram
# 319   CID100002801  N06AA04     clomipramine
# 355   CID100002995  N06AA01      desipramine
# 419   CID100003155  N06AA16        dothiepin
# 422   CID100003158  N06AA12          doxepin
# 493   CID100003386  N06AB03       fluoxetine
# 503   CID100003404  N06AB08      fluvoxamine
# 569   CID100003675  N06AF03       phenelzine
# 582   CID100003696  N06AA02       imipramine
# 603   CID100003759  N06AF01    isocarboxazid
# 656   CID100004011  N06AA21      maprotiline
# 712   CID100004184  N06AX03        mianserin
# 725   CID100004205  N06AX11      mirtazapine
# 728   CID100004235  N06AG02      moclobemide
# 748   CID100004449  N06AX06       nefazodone
# 781   CID100004543  N06AA10    nortriptyline
# 821   CID100004691  N06AB05       paroxetine
# 901   CID100004976  N06AA11    protriptyline
# 942   CID100005203  N06AB06       sertraline
# 1022  CID100005530  N06AF04  tranylcypromine
# 1024  CID100005533  N06AX05        trazodone
# 1047  CID100005584  N06AA06     trimipramine
# 1060  CID100005656  N06AX16      venlafaxine
# 1212  CID100055480  N06AX17      milnacipran
# 1236  CID100060834  N06AX21       duloxetine
# 1260  CID100065856  N06AX18       reboxetine
# 1290  CID100082148  N06AX22      agomelatine
# 1328  CID100125017  N06AX23   desvenlafaxine

# %%
# Definir una función para combinar los dfs de los archivos de perturbaciones, experimentos y líneas celulares

def add_LINCS_info(antidepressants, pert_info, inst_info, cell_info):

    # Añadir el pert_id de los antidepresivos al archivo anterior, basado en el nombre de la perturbación (pert_iname = name)
    antidepressants = pd.merge(antidepressants, pert_info[["pert_id", "pert_iname"]], on="pert_iname")

    # Contar el número de perturbaciones por cada pert_id (NOTA: un pert_iname puede tener múltiples pert_ids asociados), y añadir la columna
    name_counts = pert_info.groupby("pert_iname")["pert_id"].count().reset_index()
    name_counts.rename(columns={"pert_id": "pert_count"}, inplace=True)
    antidepressants = pd.merge(antidepressants, name_counts, on="pert_iname")

    # Contar el número de líneas celulares por cada pert_id (NOTA: un pert_id puede tener múltiples líneas celulares asociadas), y añadir la columna
    cell_line_counts = inst_info.groupby("pert_id")["cell_id"].nunique().reset_index()
    cell_line_counts.rename(columns={"cell_id": "cell_id_count"}, inplace=True)
    antidepressants = pd.merge(antidepressants, cell_line_counts, on="pert_id")

    # Añadir la información del archivo de experimentos, basado en el id de la perturbación (pert_id)
    antidepressants = pd.merge(antidepressants, inst_info.drop(columns=["pert_iname"]), on="pert_id")

    # Añadir la información del archivo de células, basado en el id de la línea celular (cell_id)
    antidepressants = pd.merge(antidepressants, cell_info, on="cell_id")

    return antidepressants

# %% [markdown]
# # Fase 1 (GSE92742)

# %%
# Leer los archivos necesarios para la fase 1

pert_info = pd.read_csv("GSE92742_Broad_LINCS_pert_info.txt", sep="\t")
inst_info = pd.read_csv("GSE92742_Broad_LINCS_inst_info.txt", sep="\t")
cell_info = pd.read_csv("GSE92742_Broad_LINCS_cell_info.txt", sep="\t")

# Emplear la función definida para crear un df con los datos de la fase 1

antidepressants_1 = add_LINCS_info(antidepressants, pert_info, inst_info, cell_info)

display(antidepressants_1)

# Guardar el archivo con los datos de la fase 1

antidepressants_1.to_csv("LINCS_ad_phase1.tsv", sep="\t", index=False)
# Out:
# /var/folders/4j/_wlvdhrs0dd1d3rhtdkfwnj00000gn/T/ipykernel_2932/956749984.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   inst_info = pd.read_csv("GSE92742_Broad_LINCS_inst_info.txt", sep="\t")
#                cid      atc       pert_iname        pert_id  pert_count  \
# 0     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 1     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 2     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 3     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 4     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# ...            ...      ...              ...            ...         ...
# 3936  CID100005530  N06AF04  tranylcypromine  BRD-K88809146           3
# 3937  CID100065856  N06AX18       reboxetine  BRD-K32814891           3
# 3938  CID100065856  N06AX18       reboxetine  BRD-K32814891           3
# 3939  CID100065856  N06AX18       reboxetine  BRD-K32814891           3
# 3940  CID100065856  N06AX18       reboxetine  BRD-K32814891           3
#
#       cell_id_count                                     inst_id  \
# 0                13        CPC004_A375_6H_X1_B3_DUO52HI53LO:J08
# 1                13        CPC004_A375_6H_X2_B3_DUO52HI53LO:J08
# 2                13        CPC004_A375_6H_X3_B3_DUO52HI53LO:J08
# 3                13        CPC015_A375_6H_X1_B4_DUO52HI53LO:L09
# 4                13        CPC015_A375_6H_X2_B4_DUO52HI53LO:L09
# ...             ...                                         ...
# 3936              5     NMH002_FIBRNPC_6H_X3_B6_DUO52HI53LO:H08
# 3937              3     NMH001_FIBRNPC_6H_X1_B6_DUO52HI53LO:N11
# 3938              3    NMH001_FIBRNPC_24H_X1_B6_DUO52HI53LO:N11
# 3939              3    NMH001_FIBRNPC_24H_X3_B6_DUO52HI53LO:N11
# 3940              3  NMH001_FIBRNPC_6H_X2.L2_B6_DUO52HI53LO:N11
#
#                     rna_plate rna_well pert_type  ...  modification  \
# 0           CPC004_A375_6H_X1      J08    trt_cp  ...          -666
# 1           CPC004_A375_6H_X2      J08    trt_cp  ...          -666
# 2           CPC004_A375_6H_X3      J08    trt_cp  ...          -666
# 3           CPC015_A375_6H_X1      L09    trt_cp  ...          -666
# 4           CPC015_A375_6H_X2      L09    trt_cp  ...          -666
# ...                       ...      ...       ...  ...           ...
# 3936     NMH002_FIBRNPC_6H_X3      H08    trt_cp  ...          -666
# 3937     NMH001_FIBRNPC_6H_X1      N11    trt_cp  ...          -666
# 3938    NMH001_FIBRNPC_24H_X1      N11    trt_cp  ...          -666
# 3939    NMH001_FIBRNPC_24H_X3      N11    trt_cp  ...          -666
# 3940  NMH001_FIBRNPC_6H_X2.L2      N11    trt_cp  ...          -666
#
#      sample_type  primary_site             subtype original_growth_pattern  \
# 0          tumor          skin  malignant melanoma                adherent
# 1          tumor          skin  malignant melanoma                adherent
# 2          tumor          skin  malignant melanoma                adherent
# 3          tumor          skin  malignant melanoma                adherent
# 4          tumor          skin  malignant melanoma                adherent
# ...          ...           ...                 ...                     ...
# 3936      normal          skin                -666                adherent
# 3937      normal          skin                -666                adherent
# 3938      normal          skin                -666                adherent
# 3939      normal          skin                -666                adherent
# 3940      normal          skin                -666                adherent
#
#      provider_catalog_id original_source_vendor donor_age donor_sex  \
# 0               CRL-1619                   ATCC        54         F
# 1               CRL-1619                   ATCC        54         F
# 2               CRL-1619                   ATCC        54         F
# 3               CRL-1619                   ATCC        54         F
# 4               CRL-1619                   ATCC        54         F
# ...                  ...                    ...       ...       ...
# 3936                -666                   -666      -666      -666
# 3937                -666                   -666      -666      -666
# 3938                -666                   -666      -666      -666
# 3939                -666                   -666      -666      -666
# 3940                -666                   -666      -666      -666
#
#      donor_ethnicity
# 0               -666
# 1               -666
# 2               -666
# 3               -666
# 4               -666
# ...              ...
# 3936            -666
# 3937            -666
# 3938            -666
# 3939            -666
# 3940            -666
#
# [3941 rows x 28 columns]

# %% [markdown]
# # Fase 2 (GSE70138)

# %%
# Leer los archivos necesarios para la fase 2

pert_info = pd.read_csv("GSE70138_Broad_LINCS_pert_info.txt", sep="\t")
inst_info = pd.read_csv("GSE70138_Broad_LINCS_inst_info.txt", sep="\t")
cell_info = pd.read_csv("GSE70138_Broad_LINCS_cell_info.txt", sep="\t")

# Emplear la función definida para crear un df con los datos de la fase 2

antidepressants_2 = add_LINCS_info(antidepressants, pert_info, inst_info, cell_info)

display(antidepressants_2)

# Guardar el archivo con los datos de la fase 2

antidepressants_2.to_csv("LINCS_ad_phase2.tsv", sep="\t", index=False)
# Out:
#                cid      atc       pert_iname        pert_id  pert_count  \
# 0     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 1     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 2     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 3     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# 4     CID100000444  N06AX12        bupropion  BRD-A05186015           1
# ...            ...      ...              ...            ...         ...
# 3649  CID100005530  N06AF04  tranylcypromine  BRD-K47029922           1
# 3650  CID100005530  N06AF04  tranylcypromine  BRD-K47029922           1
# 3651  CID100005530  N06AF04  tranylcypromine  BRD-K47029922           1
# 3652  CID100005530  N06AF04  tranylcypromine  BRD-K47029922           1
# 3653  CID100005530  N06AF04  tranylcypromine  BRD-K47029922           1
#
#       cell_id_count                       inst_id cell_id  \
# 0                 7  REP.A011_A375_24H_X1_B24:F01    A375
# 1                 7  REP.A011_A375_24H_X1_B24:F02    A375
# 2                 7  REP.A011_A375_24H_X1_B24:F03    A375
# 3                 7  REP.A011_A375_24H_X1_B24:F04    A375
# 4                 7  REP.A011_A375_24H_X1_B24:F05    A375
# ...             ...                           ...     ...
# 3649             19     LJP008_SKL_24H_X3_B21:N08     SKL
# 3650             19     LJP008_SKL_24H_X3_B21:N09     SKL
# 3651             19     LJP008_SKL_24H_X3_B21:N10     SKL
# 3652             19     LJP008_SKL_24H_X3_B21:N11     SKL
# 3653             19     LJP008_SKL_24H_X3_B21:N12     SKL
#
#                      det_plate det_well  ... modification  sample_type  \
# 0     REP.A011_A375_24H_X1_B24      F01  ...         -666        tumor
# 1     REP.A011_A375_24H_X1_B24      F02  ...         -666        tumor
# 2     REP.A011_A375_24H_X1_B24      F03  ...         -666        tumor
# 3     REP.A011_A375_24H_X1_B24      F04  ...         -666        tumor
# 4     REP.A011_A375_24H_X1_B24      F05  ...         -666        tumor
# ...                        ...      ...  ...          ...          ...
# 3649     LJP008_SKL_24H_X3_B21      N08  ...         -666      primary
# 3650     LJP008_SKL_24H_X3_B21      N09  ...         -666      primary
# 3651     LJP008_SKL_24H_X3_B21      N10  ...         -666      primary
# 3652     LJP008_SKL_24H_X3_B21      N11  ...         -666      primary
# 3653     LJP008_SKL_24H_X3_B21      N12  ...         -666      primary
#
#      primary_site                               subtype  \
# 0            skin                    malignant melanoma
# 1            skin                    malignant melanoma
# 2            skin                    malignant melanoma
# 3            skin                    malignant melanoma
# 4            skin                    malignant melanoma
# ...           ...                                   ...
# 3649       muscle  normal primary skeletal muscle cells
# 3650       muscle  normal primary skeletal muscle cells
# 3651       muscle  normal primary skeletal muscle cells
# 3652       muscle  normal primary skeletal muscle cells
# 3653       muscle  normal primary skeletal muscle cells
#
#       original_growth_pattern provider_catalog_id original_source_vendor  \
# 0                    adherent            CRL-1619                   ATCC
# 1                    adherent            CRL-1619                   ATCC
# 2                    adherent            CRL-1619                   ATCC
# 3                    adherent            CRL-1619                   ATCC
# 4                    adherent            CRL-1619                   ATCC
# ...                       ...                 ...                    ...
# 3649                 adherent             CC-2561                  LONZA
# 3650                 adherent             CC-2561                  LONZA
# 3651                 adherent             CC-2561                  LONZA
# 3652                 adherent             CC-2561                  LONZA
# 3653                 adherent             CC-2561                  LONZA
#
#      donor_age donor_sex donor_ethnicity
# 0           54         F            -666
# 1           54         F            -666
# 2           54         F            -666
# 3           54         F            -666
# 4           54         F            -666
# ...        ...       ...             ...
# 3649      -666      -666            -666
# 3650      -666      -666            -666
# 3651      -666      -666            -666
# 3652      -666      -666            -666
# 3653      -666      -666            -666
#
# [3654 rows x 29 columns]
